# %% [markdown]
# <a href="https://colab.research.google.com/github/manganijatin/finalproj-FRT-/blob/main/Data_Preprocessing_Working_Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing Dataset

# %%
dataset = pd.read_csv('netflixdata.csv', header = None)
transactions=[]
for i in range(0,7):
  transactions.append([str(dataset.values[i,j]) for j in range(0,3)])
print(dataset)
# Out:
#              0            1           2             3             4         5  \
# 0          RRR       Dhruva      temper  Rangasthalam  student no 1  bahubali
# 1          RRR       temper    bahubali           NaN           NaN       NaN
# 2         KGF1        KGF 2         NaN           NaN           NaN       NaN
# 3         KGF1        KGF 2         WAR      bahubali           NaN       NaN
# 4          WAR      Dhoom 1     Dhoom 2           NaN           NaN       NaN
# 5          WAR      Dhoom 1     dhoom 2       dhoom 3           NaN       NaN
# 6       dhoom3           PK    3 idiots           NaN           NaN       NaN
# 7    3 idiots       Friends         NaN           NaN           NaN       NaN
# 8   Moneyheist  Breakingbad         NaN           NaN           NaN       NaN
# 9          RRR     bahubali  Magadheera          Eega           NaN       NaN
# 10        KGF1        KGF 2    bahubali     bahubali2           NaN       NaN
# 11  Magadeera          Eega    bahubali           NaN           NaN       NaN
# 12  Moneyheist  Breakingbad        dark           NaN           NaN       NaN
# 13    bahubali    bahubali2         RRR           NaN           NaN       NaN
#
#              6           7     8
# 0   bahubali 2  Magadheera  Eega
# 1          NaN         NaN   NaN
# 2          NaN         NaN   NaN
# 3          NaN         NaN   NaN
# 4          NaN         NaN   NaN
# 5          NaN         NaN   NaN
# 6          NaN         NaN   NaN
# 7          NaN         NaN   NaN
# 8          NaN         NaN   NaN
# 9          NaN         NaN   NaN
# 10         NaN         NaN   NaN
# 11         NaN         NaN   NaN
# 12         NaN         NaN   NaN
# 13         NaN         NaN   NaN

# %% [markdown]
# # New Section

# %% [markdown]
# results

# %%
# !pip install apyori
from apyori import apriori
rules=apriori(transactions = transactions, min_support=0.03)

results=list(rules)
print(results)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)
# [RelationRecord(items=frozenset({'3 idiots'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'Dhoom 1'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhoom 1'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'Dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhoom 2'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'Dhruva'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhruva'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'KGF 2'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'KGF 2'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'KGF1'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'KGF1'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'PK'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'RRR'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RRR'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'WAR'}), support=0.42857142857142855, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WAR'}), confidence=0.42857142857142855, lift=1.0)]), RelationRecord(items=frozenset({'bahubali'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bahubali'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'dhoom 2'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'dhoom3'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'dhoom3'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'nan'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'temper'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'temper'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'3 idiots', 'PK'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots', 'PK'}), confidence=0.14285714285714285, lift=1.0), OrderedStatistic(items_base=frozenset({'3 idiots'}), items_add=frozenset({'PK'}), confidence=1.0, lift=7.0), OrderedStatistic(items_base=frozenset({'PK'}), items_add=frozenset({'3 idiots'}), confidence=1.0, lift=7.0)]), RelationRecord(items=frozenset({'3 idiots', 'dhoom3'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots', 'dhoom3'}), confidence=0.14285714285714285, lift=1.0), OrderedStatistic(items_base=frozenset({'3 idiots'}), items_add=frozenset({'dhoom3'}), confidence=1.0, lift=7.0), OrderedStatistic(items_base=frozenset({'dhoom3'}), items_add=frozenset({'3 idiots'}), confidence=1.0, lift=7.0)]), RelationRecord(items=frozenset({'Dhoom 1', 'Dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items ...

# %% [markdown]
# # New Section

# %%
from tabulate import tabulate
print(tabulate([[results]], headers=['movie1', 'movie2','support']))
# Out:
# movie1
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# [RelationRecord(items=frozenset({'3 idiots'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'Dhoom 1'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhoom 1'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'Dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhoom 2'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'Dhruva'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Dhruva'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'KGF 2'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'KGF 2'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'KGF1'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'KGF1'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'PK'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'RRR'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RRR'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'WAR'}), support=0.42857142857142855, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WAR'}), confidence=0.42857142857142855, lift=1.0)]), RelationRecord(items=frozenset({'bahubali'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bahubali'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'dhoom 2'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'dhoom3'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'dhoom3'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'nan'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.14285714285714285, lift=1.0)]), RelationRecord(items=frozenset({'temper'}), support=0.2857142857142857, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'temper'}), confidence=0.2857142857142857, lift=1.0)]), RelationRecord(items=frozenset({'3 idiots', 'PK'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots', 'PK'}), confidence=0.14285714285714285, lift=1.0), OrderedStatistic(items_base=frozenset({'3 idiots'}), items_add=frozenset({'PK'}), confidence=1.0, lift=7.0), OrderedStatistic(items_base=frozenset({'PK'}), items_add=frozenset({'3 idiots'}), confidence=1.0, lift=7.0)]), RelationRecord(items=frozenset({'3 idiots', 'dhoom3'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 idiots', 'dhoom3'}), confidence=0.14285714285714285, lift=1.0), OrderedStatistic(items_base=frozenset({'3 idiots'}), items_add=frozenset({'dhoom3'}), confidence=1.0, lift=7.0), OrderedStatistic(items_base=frozenset({'dhoom3'}), items_add=frozenset({'3 idiots'}), confidence=1.0, lift=7.0)]), RelationRecord(items=frozenset({'Dhoom 1', 'Dhoom 2'}), support=0.14285714285714285, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items ...

# %% [markdown]
# # New Section
